# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\zacha\神州\data\csv\monroe.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area(sqft)',fontsize=10)
plt.ylabel('Price(USD)',fontsize=10)
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,model.predict(df[['area']]),color='blue');

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
model.predict(np.array([3300]).reshape(1,1))
# Out:
# C:\Users\zacha\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [135.78767123]
# 180616.43835616432

# %%
df2 = pd.read_csv(r"C:\Users\zacha\神州\data\csv\areas.csv")
df2.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = model.predict(df2)
print(p)
# Out:
# [ 316404.10958904  384297.94520548  492928.08219178  661304.79452055
#   740061.64383562  799808.21917808  926090.75342466  650441.78082192
#   825607.87671233  492928.08219178 1402705.47945205 1348390.4109589
#  1144708.90410959]

# %%
df2['prices'] = p

# %%
df2.to_csv('areas_predictions.csv',index=False)

# %%
df3 = pd.read_csv(r"C:\Users\zacha\神州\data\csv\areas_predictions.csv")
df3.head()
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %%
df3.rename(columns = {'prices':'price_prediction'},inplace=True)
df3.head()
# Out:
#    area  price_prediction
# 0  1000     316404.109589
# 1  1500     384297.945205
# 2  2300     492928.082192
# 3  3540     661304.794521
# 4  4120     740061.643836
